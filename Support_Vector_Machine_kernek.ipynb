# %% [markdown]
# <a href="https://colab.research.google.com/github/Prathambiradr12345/Machine-_learning/blob/main/Support_Vector_Machine_kernek.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap
# Import make_circles directly from sklearn.datasets
from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='bwr')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)

# %%
classifier = SVC(kernel="linear")
classifier.fit(X_train, y_train.ravel())
y_pred = classifier.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.55

# %%
from IPython import get_ipython
from IPython.display import display
# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.axes._axes import _log as matplotlib_axes_logger
from mpl_toolkits import mplot3d
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from matplotlib.colors import ListedColormap
# Import make_circles directly from sklearn.datasets
from sklearn.datasets import make_circles
X, y = make_circles(100, factor=.1, noise=.1)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='bwr')
# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
# %%
classifier = SVC(kernel="linear")
classifier.fit(X_train, y_train.ravel())
y_pred = classifier.predict(X_test)
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# %%
# Use single-letter color abbreviations or numerical RGB values for ListedColormap
zero_one_colourmap = ListedColormap(('b', 'r'))  # or ListedColormap([(0, 0, 1), (1, 0, 0)])
def plot_decision_boundary(X, y, clf):
    X_set, y_set = X, y
    X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1,
                                 stop = X_set[:, 0].max() + 1,
                                 step = 0.01),
                       np.arange(start = X_set[:, 1].min() - 1,
                                 stop = X_set[:, 1].max() + 1,
                                 step = 0.01))

    plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
                                             X2.ravel()]).T).reshape(X1.shape),
               alpha = 0.75,
               cmap = zero_one_colourmap)
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = (zero_one_colourmap)(i), label = j)
    plt.title('SVM Decision Boundary')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    return plt.show()
# %%
plot_decision_boundary(X, y, classifier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-03e91619149b> in <cell line: 52>()
#      50     return plt.show()
#      51 # %%
# ---> 52 plot_decision_boundary(X, y, classifier)
#
# <ipython-input-30-03e91619149b> in plot_decision_boundary(X, y, clf)
#      35                                  step = 0.01))
#      36
# ---> 37     plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
#      38                                              X2.ravel()]).T).reshape(X1.shape),
#      39                alpha = 0.75,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2936 @_copy_docstring_and_deprecators(Axes.contourf)
#    2937 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2938     __ret = gca().contourf(
#    2939         *args, **({"data": data} if data is not None else {}), **kwargs
# ...

# %%
# Use single-letter color abbreviations or numerical RGB values for ListedColormap
#zero_one_colourmap = ListedColormap(('b', 'r'))  # or ListedColormap([(0, 0, 1), (1, 0, 0)])
# Replace 'b' and 'r' with 'blue' and 'red' respectively
zero_one_colourmap = ListedColormap(('blue', 'red')) # or ListedColormap([(0, 0, 1), (1, 0, 0)])

# Rest of the plot_decision_boundary function code remains the same...

# %%
def plot_3d_plot(X, y):
    r = np.exp(-(X ** 2).sum(1))
    ax = plt.subplot(projection='3d')
    ax.scatter3D(X[:, 0], X[:, 1], r, c=y, s=100, cmap='bwr')
    ax.set_xlabel('X1')
    ax.set_ylabel('X2')
    ax.set_zlabel('y')
    return ax
plot_3d_plot(X,y)
# Out:
# <Axes3D: xlabel='X1', ylabel='X2', zlabel='y'>

# %%
rbf_classifier = SVC(kernel="rbf")
rbf_classifier.fit(X_train, y_train)
y_pred = rbf_classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
plot_decision_boundary(X, y, rbf_classifier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-8a5da2770255> in <cell line: 1>()
# ----> 1 plot_decision_boundary(X, y, rbf_classifier)
#
# <ipython-input-30-03e91619149b> in plot_decision_boundary(X, y, clf)
#      35                                  step = 0.01))
#      36
# ---> 37     plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
#      38                                              X2.ravel()]).T).reshape(X1.shape),
#      39                alpha = 0.75,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2936 @_copy_docstring_and_deprecators(Axes.contourf)
#    2937 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2938     __ret = gca().contourf(
#    2939         *args, **({"data": data} if data is not None else {}), **kwargs
#    2940     )
#
# ...

# %%
# Use single-letter color abbreviations or numerical RGB values for ListedColormap
# zero_one_colourmap = ListedColormap(('b', 'r'))  # or ListedColormap([(0, 0, 1), (1, 0, 0)])
# Replace 'b' and 'r' with 'blue' and 'red' respectively
zero_one_colourmap = ListedColormap(('blue', 'red'))  # or ListedColormap([(0, 0, 1), (1, 0, 0)])

def plot_decision_boundary(X, y, clf):
    X_set, y_set = X, y
    X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1,
                                     stop=X_set[:, 0].max() + 1,
                                     step=0.01),
                         np.arange(start=X_set[:, 1].min() - 1,
                                     stop=X_set[:, 1].max() + 1,
                                     step=0.01))

    plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
                                                 X2.ravel()]).T).reshape(X1.shape),
                 alpha=0.75,
                 cmap=zero_one_colourmap)  # Use the corrected colormap here
    plt.xlim(X1.min(), X1.max())
    plt.ylim(X2.min(), X2.max())
    for i, j in enumerate(np.unique(y_set)):
        plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                    c=(zero_one_colourmap)(i), label=j)  # Use the corrected colormap here
    plt.title('SVM Decision Boundary')
    plt.xlabel('X1')
    plt.ylabel('X2')
    plt.legend()
    return plt.show()

# %%
plot_decision_boundary(X, y, rbf_classifier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-36-8a5da2770255> in <cell line: 1>()
# ----> 1 plot_decision_boundary(X, y, rbf_classifier)
#
# <ipython-input-35-b7c070bcbcb6> in plot_decision_boundary(X, y, clf)
#      13                                      step=0.01))
#      14
# ---> 15     plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
#      16                                                  X2.ravel()]).T).reshape(X1.shape),
#      17                  alpha=0.75,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2936 @_copy_docstring_and_deprecators(Axes.contourf)
#    2937 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2938     __ret = gca().contourf(
#    2939         *args, **({"data": data} if data is not None else {}), **kwargs
#    2940     )
#
# ...

# %%
poly_classifier = SVC(kernel="poly",degree=2)
poly_classifier.fit(X_train, y_train)
y_pred = poly_classifier.predict(X_test)

# %%
accuracy_score(y_test, y_pred)
# Out:
# 1.0

# %%
plot_decision_boundary(X, y, poly_classifier)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-687b771426f4> in <cell line: 1>()
# ----> 1 plot_decision_boundary(X, y, poly_classifier)
#
# <ipython-input-35-b7c070bcbcb6> in plot_decision_boundary(X, y, clf)
#      13                                      step=0.01))
#      14
# ---> 15     plt.contourf(X1, X2, clf.predict(np.array([X1.ravel(),
#      16                                                  X2.ravel()]).T).reshape(X1.shape),
#      17                  alpha=0.75,
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/pyplot.py in contourf(data, *args, **kwargs)
#    2936 @_copy_docstring_and_deprecators(Axes.contourf)
#    2937 def contourf(*args, data=None, **kwargs) -> QuadContourSet:
# -> 2938     __ret = gca().contourf(
#    2939         *args, **({"data": data} if data is not None else {}), **kwargs
#    2940     )
#
# ...

# %%
X
# Out:
# array([[-0.08264241, -0.04388379],
#        [-0.03667476, -0.12112248],
#        [ 0.05605489,  1.04821431],
#        [ 0.98405517, -0.02029914],
#        [-0.02578401, -0.01366043],
#        [-0.86863174,  0.07907894],
#        [ 0.53119361,  0.57969939],
#        [-0.89214548,  0.58798942],
#        [ 0.1917048 ,  0.11944388],
#        [-0.55676276,  0.87606592],
#        [-0.82212954, -0.17979818],
#        [ 0.74452414,  0.05121681],
#        [-0.22413634, -0.0989573 ],
#        [-0.87654221,  0.19604363],
#        [-0.54051555, -0.82929456],
#        [-0.82354572,  0.79514482],
#        [-0.72585153, -0.80537758],
#        [-0.85456362, -0.31984613],
#        [ 0.23844466,  0.12059744],
#        [ 0.7709177 ,  0.70678742],
#        [-0.07248127, -0.08536888],
#        [ 0.10059012, -0.09571109],
#        [-0.50725088,  0.91259686],
#        [-0.19530329,  1.15910988],
#        [-0.10537101,  0.10231667],
#        [ 0.60984786,  0.76357144],
#        [ 1.0482327 , -0.35870389],
# ...

# %%
np.exp(-(X**2)).sum(1)
# Out:
# array([1.99126957, 1.9840923 , 1.33014913, 1.37929153, 1.99914882,
#        1.46400179, 1.46873439, 1.15886681, 1.94975083, 1.19763412,
#        1.47688948, 1.57184523, 1.94125916, 1.42608476, 1.24936746,
#        1.03890775, 1.1132157 , 1.38453186, 1.93029174, 1.15874561,
#        1.98749889, 1.98081386, 1.20794926, 1.22349641, 1.97854427,
#        1.24761135, 1.21253891, 1.99360103, 1.99152473, 1.12169255,
#        1.98663232, 1.98309859, 1.99666668, 1.99255953, 1.20195548,
#        1.30756384, 1.97839826, 1.31780049, 1.94867411, 1.98318278,
#        1.92769353, 1.45905699, 1.93651229, 1.27333362, 1.41658705,
#        1.90673229, 1.41731017, 1.40377964, 1.36198829, 1.94511341,
#        1.95896317, 1.31648693, 1.95997175, 1.38306212, 1.08742785,
#        1.9522326 , 1.33744221, 1.29053992, 1.81439986, 1.44065318,
#        1.13953493, 1.42903078, 1.28516804, 1.99752364, 1.97105291,
#        1.33230299, 1.99253445, 1.99846711, 1.99440655, 1.9855337 ,
# ...

# %%
X_new=np.exp(-(X**2))
plt.scatter(X_new[:, 0], X_new[:, 1], c=y, s=50, cmap='bwr')
